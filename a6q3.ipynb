# %%
##Question 3: Question 3: Dataset Comparison (10 points) 
Write a short paragraph (5 7 sentences) comparing the two datasets: 
-	Key similarities (e.g., variable type, temporal resolution) 
	Key differences (e.g., spatial resolution, data source, methodology) 
	Advantages or limitations of each dataset
# Out:
#   Cell In[8], line 2
#     Write a short paragraph (5 7 sentences) comparing the two datasets:
#           ^
# SyntaxError: invalid syntax

# %%
# Both the CRU TS4.09 and GISTEMP 1200 datasets measure near surface temperature at a monthly time step, which makes them useful for looking at long term climate trends over similar time periods. One thing they have in common is that both combine land-based station records with sea-surface temperature data to create gridded global products spanning well over a century. Where they differ most noticeably is spatial resolution, as CRU uses a finer 0.5 x 0.5 degree grid while GISTEMP works on a coarser 2 x 2 degree grid and fills in gaps by interpolating over distances up to 1,200 km. They also come from different institutions and use different source data, as CRU is developed by the Climatic Research Unit at the University of East Anglia while GISTEMP is a NASA product built from the GHCNv4 land dataset and ERSSTv5 ocean temperatures. The finer resolution of CRU makes it better suited for regional analysis, though it can leave blank areas where station coverage is sparse, like parts of the Arctic. GISTEMP handles those gaps better through its wider interpolation radius, but that approach can introduce some uncertainty in areas where few weather stations exist.
